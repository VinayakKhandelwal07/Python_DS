# %%
import pandas as pd 
import numpy as np

# %%
dt = {
    "Name": ['Vinayak','manvik','Keshav'],
    "Branch": ['CS','CS','CS'],
    "Year": [3,3,3],
    "City":['jAIPUR','jAIPUR','NAGORE'],
    
}
dt
# Out:
# {'Name': ['Vinayak', 'manvik', 'Keshav'],
#  'Branch': ['CS', 'CS', 'CS'],
#  'Year': [3, 3, 3],
#  'City': ['jAIPUR', 'jAIPUR', 'NAGORE']}

# %%
df = pd.DataFrame(dt)
df
# Out:
#       Name Branch  Year    City
# 0  Vinayak     CS     3  jAIPUR
# 1   manvik     CS     3  jAIPUR
# 2   Keshav     CS     3  NAGORE

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name']
# Out:
# 0    Vinayak
# 1     manvik
# 2     Keshav
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[['Year','Branch']]
# Out:
#    Year Branch
# 0     3     CS
# 1     3     CS
# 2     3     CS

# %%
df[1:3]
# Out:
#      Name Branch  Year    City
# 1  manvik     CS     3  jAIPUR
# 2  Keshav     CS     3  NAGORE

# %%
df[1:2]
# Out:
#      Name Branch  Year    City
# 1  manvik     CS     3  jAIPUR

# %%
df.loc[1:2]
# Out:
#      Name Branch  Year    City
# 1  manvik     CS     3  jAIPUR
# 2  Keshav     CS     3  NAGORE

# %%
df[1:3][["Name","Branch"]]
# Out:
#      Name Branch
# 1  manvik     CS
# 2  Keshav     CS

# %%
df.loc[1:2,["Name","Branch"]]
# Out:
#      Name Branch
# 1  manvik     CS
# 2  Keshav     CS

# %%
df.iloc[1:3,0:4]
# Out:
#      Name Branch  Year    City
# 1  manvik     CS     3  jAIPUR
# 2  Keshav     CS     3  NAGORE

# %%
df.loc[3:,['Branch','Year','City']]
# Out:
# Empty DataFrame
# Columns: [Branch, Year, City]
# Index: []

# %%
df.iloc[3:,1:]
# Out:
# Empty DataFrame
# Columns: [Branch, Year, City]
# Index: []

# %%
import pandas as pd

# %%
df = pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail(2)
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
df[df['brand'] == "Royal Enfield"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 df[df['brand'] == "Royal Enfield"].mean()
#
# File c:\Users\Vinayak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\Vinayak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
# ...

# %%
bullet = df[df['brand'] == "Royal Enfield"] # Single condition

# %%
bullet.head()
# Out:
#                                    bike_name     price       city  kms_driven  \
# 1                Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
# 23        Royal Enfield Classic Chrome 500cc  121700.0     Kalyan     24520.0
# 36               Royal Enfield Classic 350cc   98800.0      Kochi     39000.0
#
#            owner  age  power          brand
# 1    First Owner  4.0  350.0  Royal Enfield
# 8    First Owner  3.0  350.0  Royal Enfield
# 9   Second Owner  7.0  500.0  Royal Enfield
# 23   First Owner  5.0  500.0  Royal Enfield
# 36   First Owner  5.0  350.0  Royal Enfield

# %%
bullet.shape
# Out:
# (4178, 8)

# %%
bullet2 = df[(df['brand'] == "Royal Enfield") & (df['age']<=2) & (df['owner']=='First Owner')]            # Multiply conditions

# %%
bullet2.head()
# Out:
#                                 bike_name     price         city  kms_driven  \
# 38      Royal Enfield Thunderbird X 500cc  190500.0   Samastipur      4550.0
# 81        Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai      3800.0
# 139  Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara     14000.0
# 157  Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara     14000.0
# 194           Royal Enfield Electra 350cc  145000.0    Bangalore      4000.0
#
#            owner  age  power          brand
# 38   First Owner  2.0  500.0  Royal Enfield
# 81   First Owner  2.0  650.0  Royal Enfield
# 139  First Owner  2.0  410.0  Royal Enfield
# 157  First Owner  2.0  410.0  Royal Enfield
# 194  First Owner  2.0  350.0  Royal Enfield

# %%
bullet2.shape
# Out:
# (84, 8)

# %%
bullet2["city"].nunique()
# Out:
# 28

# %%
bullet2["city"].unique()
# Out:
# array(['Samastipur', 'Navi Mumbai', 'Vadodara', 'Bangalore',
#        'Hamirpur(hp)', 'Mumbai', 'Delhi', 'Guwahati', 'Haldwani',
#        'Ahmedabad', 'Bardhaman', 'Silchar', 'Sibsagar', 'Kharar',
#        'Baripara', 'Sonipat', 'Pune', 'Farukhabad', 'Sultanpur',
#        'Hyderabad', 'Gurgaon', 'Faridabad', 'Kota', 'Thane', 'Nellore',
#        'Alipore', 'Ghaziabad', 'Noida'], dtype=object)

# %%
bullet2['city'].value_counts()
# Out:
# city
# Delhi           18
# Mumbai          10
# Bangalore        6
# Ahmedabad        6
# Vadodara         4
# Guwahati         4
# Faridabad        4
# Hyderabad        3
# Ghaziabad        3
# Sibsagar         2
# Bardhaman        2
# Navi Mumbai      2
# Gurgaon          2
# Alipore          2
# Farukhabad       2
# Kharar           2
# Silchar          1
# Haldwani         1
# Hamirpur(hp)     1
# Samastipur       1
# Sultanpur        1
# Pune             1
# Baripara         1
# Sonipat          1
# Thane            1
# Kota             1
# Nellore          1
# Noida            1
# Name: count, dtype: int64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
bullet =df[(df['city'] == "jaipur" )& (df["age"]<=2 ) &(df["owner"] == "First Owner")]

# %%
bullet
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
Bikes =  df[(df['brand'] == "KTM") | (df["brand"]== "Jawa")]

# %%
Bikes
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
Bikes['brand'].value_counts()
# Out:
# brand
# KTM     1077
# Jawa      10
# Name: count, dtype: int64

# %%
if "Jaipur" in Bikes['city'].unique():
      print("Present")
else: 
      print("Absent")
# Out:
# Present

# %%
Bikes[Bikes['city'] == "Jaipur"]
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
bike = df[((df['brand'] == "KTM") | (df['brand'] == "Jawa")) & (df['city'] == "Jaipur")]
bike
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
bullet.shape
# Out:
# (7324,)

# %%
bullet = df['brand'] == "Royal Enfield"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bullet = df['brand'] == "Royal Enfield"
#
# NameError: name 'df' is not defined

# %%
import numpy as np
import pandas as pd

# %%
data = {'A':[2,5,np.nan,8,np.nan,9],
       'B':[np.nan,45,np.nan,89,63,np.nan], 
       'C':[np.nan,74,np.nan,np.nan,85,4], 
       'D':[10,20,30,40,50,60]}
data
# Out:
# {'A': [2, 5, nan, 8, nan, 9],
#  'B': [nan, 45, nan, 89, 63, nan],
#  'C': [nan, 74, nan, nan, 85, 4],
#  'D': [10, 20, 30, 40, 50, 60]}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#      A     B     C   D
# 0  2.0   NaN   NaN  10
# 1  5.0  45.0  74.0  20
# 2  NaN   NaN   NaN  30
# 3  8.0  89.0   NaN  40
# 4  NaN  63.0  85.0  50
# 5  9.0   NaN   4.0  60

# %%
df2.dropna()  #By Default remove all those rows  that containg missig valuses
# Out:
#      A     B     C   D
# 1  5.0  45.0  74.0  20

# %%
df2.dropna(axis = "columns")
# Out:
#     D
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60

# %%
df2.isnull().sum()
# Out:
# A    2
# B    3
# C    3
# D    0
# dtype: int64

# %%
print("Total missing values in your Dataframe :",df2.isnull().sum().sum())
# Out:
# Total missing values in your Dataframe : 8

# %%
print("Percentages of the missing values in a particular column  : \n",df2.isnull().sum()/df2.shape[0]*100)
# Out:
# Percentages of the missing values in a particular column  :
#  A    33.333333
# B    50.000000
# C    50.000000
# D     0.000000
# dtype: float64

# %%
df2.fillna(500)
# Out:
#        A      B      C   D
# 0    2.0  500.0  500.0  10
# 1    5.0   45.0   74.0  20
# 2  500.0  500.0  500.0  30
# 3    8.0   89.0  500.0  40
# 4  500.0   63.0   85.0  50
# 5    9.0  500.0    4.0  60

# %%
df2["A"].fillna(500)
# Out:
# 0      2.0
# 1      5.0
# 2    500.0
# 3      8.0
# 4    500.0
# 5      9.0
# Name: A, dtype: float64

# %%
df2['A'].mean()
# Out:
# np.float64(6.0)

# %%
df2['A'].fillna(df2['A'].mean())
# Out:
# 0    2.0
# 1    5.0
# 2    6.0
# 3    8.0
# 4    6.0
# 5    9.0
# Name: A, dtype: float64

# %%
df2['A'].median()
# Out:
# np.float64(6.5)

# %%
df2['A'].fillna(df2['A'].median())
# Out:
# 0    2.0
# 1    5.0
# 2    6.5
# 3    8.0
# 4    6.5
# 5    9.0
# Name: A, dtype: float64

# %%
df2['A'].mode()
# Out:
# 0    2.0
# 1    5.0
# 2    8.0
# 3    9.0
# Name: A, dtype: float64

# %% [markdown]
# GROUPBY

# %%
df[['owner']]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df[df['brand']=='TVS']["price"].min()
# Out:
# np.float64(5800.0)

# %%
brand_Group = df.groupby("brand")
brand_Group

# %%
brand_Group.get_group('TVS')
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
brand_Group[['price']].min()
# Out:
#                     price
# brand
# BMW              255000.0
# Bajaj              6400.0
# Benelli          110700.0
# Ducati           380000.0
# Harley-Davidson  250000.0
# Hero               5000.0
# Honda             10000.0
# Hyosung          120000.0
# Ideal            100000.0
# Indian           700000.0
# Jawa             146000.0
# KTM               55000.0
# Kawasaki         110000.0
# LML                4400.0
# MV               950000.0
# Mahindra          17800.0
# Rajdoot           75000.0
# Royal Enfield     33500.0
# Suzuki             8000.0
# TVS                5800.0
# Triumph          500000.0
# Yamaha             9400.0
# Yezdi             68000.0

# %%
brand_Group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
brand_Group[['price']].mean()
# Out:
#                         price
# brand
# BMW              5.987500e+05
# Bajaj            4.833127e+04
# Benelli          2.942000e+05
# Ducati           9.355455e+05
# Harley-Davidson  4.529988e+05
# Hero             2.382945e+04
# Honda            5.923047e+04
# Hyosung          2.491678e+05
# Ideal            1.000000e+05
# Indian           1.100000e+06
# Jawa             1.855000e+05
# KTM              1.746697e+05
# Kawasaki         4.116246e+05
# LML              4.400000e+03
# MV               1.325000e+06
# Mahindra         7.250709e+04
# Rajdoot          7.500000e+04
# Royal Enfield    9.856207e+04
# Suzuki           4.594683e+04
# TVS              4.429915e+04
# Triumph          8.274230e+05
# Yamaha           5.706896e+04
# Yezdi            6.800000e+04

# %%
brand_Group['price'].agg(min_price = 'min', max_price ='max',Avg_price ='mean')
# Out:
#                  min_price  max_price     Avg_price
# brand
# BMW               255000.0  1800000.0  5.987500e+05
# Bajaj               6400.0   195000.0  4.833127e+04
# Benelli           110700.0   785000.0  2.942000e+05
# Ducati            380000.0  1500000.0  9.355455e+05
# Harley-Davidson   250000.0  1100000.0  4.529988e+05
# Hero                5000.0   104000.0  2.382945e+04
# Honda              10000.0   800000.0  5.923047e+04
# Hyosung           120000.0   493500.0  2.491678e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.855000e+05
# KTM                55000.0   860000.0  1.746697e+05
# Kawasaki          110000.0  1100000.0  4.116246e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.325000e+06
# Mahindra           17800.0   175000.0  7.250709e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
kms_driven_Group = df.groupby("kms_driven")
kms_driven_Group

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
owner = df[['owner']]
owner
# Out:
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4      First Owner
# ...            ...
# 32643  First Owner
# 32644  First Owner
# 32645  First Owner
# 32646  First Owner
# 32647  First Owner
#
# [32648 rows x 1 columns]

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
cat_col = df.select_dtypes(include = 'O')
cat_col
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...

# %%
num_col = df.select_dtypes(exclude = 'O')
num_col
# Out:
#           price  kms_driven   age  power
# 0       35000.0     17654.0   3.0  110.0
# 1      119900.0     11000.0   4.0  350.0
# 2      600000.0       110.0   8.0  675.0
# 3       65000.0     16329.0   4.0  180.0
# 4       80000.0     10000.0   3.0  150.0
# ...         ...         ...   ...    ...
# 32643   39000.0     22000.0   4.0  100.0
# 32644   30000.0      6639.0   9.0  180.0
# 32645   60000.0     20373.0   6.0  220.0
# 32646   15600.0     84186.0  16.0  125.0
# 32647   22000.0     60857.0  13.0  150.0
#
# [32648 rows x 4 columns]

# %%
pd.concat([cat_col,num_col],axis ='columns')
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand     price  kms_driven   age  power
# 0                TVS   35000.0     17654.0   3.0  110.0
# ...

# %%
pd.merge()
